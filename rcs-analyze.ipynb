# %%
# !git clone https://github.com/bhrdj83/Efficient_ACL_via_RCS.git
# Out:
# Cloning into 'Efficient_ACL_via_RCS'...
# remote: Enumerating objects: 509, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 509 (delta 56), reused 136 (delta 42), pack-reused 352 (from 1)
# Receiving objects: 100% (509/509), 632.56 KiB | 19.17 MiB/s, done.
# Resolving deltas: 100% (278/278), done.

# %%
# !pip install git+https://github.com/fra31/auto-attack
# Out:
# ...
#   Cloning https://github.com/fra31/auto-attack to /tmp/pip-req-build-zujig81g
#   Running command git clone --filter=blob:none --quiet https://github.com/fra31/auto-attack /tmp/pip-req-build-zujig81g
#   Resolved https://github.com/fra31/auto-attack to commit a39220048b3c9f2cca9a4d3a54604793c68eca7e
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for autoattack: filename=autoattack-0.1-py3-none-any.whl size=36228 sha256=d2784da92dfc74b138327642bd8424b4180efc445da1f0e03b8001f9a552f09d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kr5m7k95/wheels/e1/e8/28/65b2724d4c7740785979eb50bf5e1b3986ead22f6c32a87f8f
# Successfully built autoattack
# ...

# %%
# !git pull origin
# Out:
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# %cd /kaggle/working/Efficient_ACL_via_RCS/SAT_RCS/ImageNet_32
# !python SAT_RCS.py --out_dir exp_dir --fraction 0.5 --epochs 100
# Out:
# /kaggle/working/Efficient_ACL_via_RCS/SAT_RCS/ImageNet_32
# 2025-10-01 21:47:36.419990: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759355256.611042      85 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759355256.669872      85 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 100%|████████████████████████████████████████| 170M/170M [00:03<00:00, 47.6MB/s]
# 49750 250
# ...
